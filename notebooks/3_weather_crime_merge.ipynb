# %%
import pandas as pd

# %%
#Crime data
crime_data = pd.read_csv("../processed_data/cleaned_crime_data.csv")
crime_data.head()
# Out:
#           ID   DATE RPTD       AREA  \
# 0    1307355  2010-02-20     NEWTON
# 1   11401303  2010-09-13    PACIFIC
# 2   70309629  2010-08-09     NEWTON
# 3   90631215  2010-01-05  HOLLYWOOD
# 4  100100501  2010-01-03    CENTRAL
#
#                                                CRIME VICT AGE VICT SEX  \
# 0                           VIOLATION OF COURT ORDER       48        M
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  Unknown        M
# 2                          OTHER MISCELLANEOUS CRIME  Unknown        M
# 3                           VIOLATION OF COURT ORDER       47        F
# 4                                    RAPE, ATTEMPTED       47        F
#
#   VICT DESCENT                   PLACE      LAT       LON  \
# 0            H  SINGLE FAMILY DWELLING  33.9825 -118.2695
# 1            W                  STREET  33.9599 -118.3962
# 2            H                   ALLEY  34.0224 -118.2524
# 3            W                  STREET  34.1016 -118.3295
# ...

# %%
#Weather data
weather_data = pd.read_csv("../processed_data/weather_2010_2019_hourly.csv")
weather_data.head()
# Out:
#               datetime  temperature  precipitation  wind_speed  rain  \
# 0  2010-01-01 00:00:00          6.2            0.0         9.3   0.0
# 1  2010-01-01 01:00:00          5.8            0.0         9.1   0.0
# 2  2010-01-01 02:00:00          5.6            0.0         9.8   0.0
# 3  2010-01-01 03:00:00          5.4            0.0        10.2   0.0
# 4  2010-01-01 04:00:00          5.4            0.0        10.7   0.0
#
#    snowfall    APREC
# 0       0.0  MISSION
# 1       0.0  MISSION
# 2       0.0  MISSION
# 3       0.0  MISSION
# 4       0.0  MISSION

# %%
weather_data.shape
# Out:
# (1840608, 7)

# %%
# Merge on both datetime and area
merged_data = pd.merge(
    crime_data,
    weather_data,
    left_on=['DATETIME OCC', 'AREA'],
    right_on=['datetime', 'APREC'],
    how='left'  
)

merged_data.head()
# Out:
#           ID   DATE RPTD       AREA  \
# 0    1307355  2010-02-20     NEWTON
# 1   11401303  2010-09-13    PACIFIC
# 2   70309629  2010-08-09     NEWTON
# 3   90631215  2010-01-05  HOLLYWOOD
# 4  100100501  2010-01-03    CENTRAL
#
#                                                CRIME VICT AGE VICT SEX  \
# 0                           VIOLATION OF COURT ORDER       48        M
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  Unknown        M
# 2                          OTHER MISCELLANEOUS CRIME  Unknown        M
# 3                           VIOLATION OF COURT ORDER       47        F
# 4                                    RAPE, ATTEMPTED       47        F
#
#   VICT DESCENT                   PLACE      LAT       LON  \
# 0            H  SINGLE FAMILY DWELLING  33.9825 -118.2695
# 1            W                  STREET  33.9599 -118.3962
# 2            H                   ALLEY  34.0224 -118.2524
# 3            W                  STREET  34.1016 -118.3295
# ...

# %%
# Drop unnecessary columns
merged_data.drop(
    columns=['AREA', 'datetime', 'APREC'],
    inplace=True
)

merged_data.head()
# Out:
#           ID   DATE RPTD                                              CRIME  \
# 0    1307355  2010-02-20                           VIOLATION OF COURT ORDER
# 1   11401303  2010-09-13  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 2   70309629  2010-08-09                          OTHER MISCELLANEOUS CRIME
# 3   90631215  2010-01-05                           VIOLATION OF COURT ORDER
# 4  100100501  2010-01-03                                    RAPE, ATTEMPTED
#
#   VICT AGE VICT SEX VICT DESCENT                   PLACE      LAT       LON  \
# 0       48        M            H  SINGLE FAMILY DWELLING  33.9825 -118.2695
# 1  Unknown        M            W                  STREET  33.9599 -118.3962
# 2  Unknown        M            H                   ALLEY  34.0224 -118.2524
# 3       47        F            W                  STREET  34.1016 -118.3295
# 4       47        F            H                   ALLEY  34.0387 -118.2488
#
# ...

# %%
merged_data = merged_data.rename(columns={"temperature": "TEMPERATURE"})
merged_data = merged_data.rename(columns={"precipitation": "PERCIPITATION"})
merged_data = merged_data.rename(columns={"wind_speed": "WIND SPEED"})
merged_data = merged_data.rename(columns={"rain": "RAIN"})
merged_data = merged_data.rename(columns={"snowfall": "SNOWFALL"})

# %%
merged_data.head()
# Out:
#           ID   DATE RPTD                                              CRIME  \
# 0    1307355  2010-02-20                           VIOLATION OF COURT ORDER
# 1   11401303  2010-09-13  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 2   70309629  2010-08-09                          OTHER MISCELLANEOUS CRIME
# 3   90631215  2010-01-05                           VIOLATION OF COURT ORDER
# 4  100100501  2010-01-03                                    RAPE, ATTEMPTED
#
#   VICT AGE VICT SEX VICT DESCENT                   PLACE      LAT       LON  \
# 0       48        M            H  SINGLE FAMILY DWELLING  33.9825 -118.2695
# 1  Unknown        M            W                  STREET  33.9599 -118.3962
# 2  Unknown        M            H                   ALLEY  34.0224 -118.2524
# 3       47        F            W                  STREET  34.1016 -118.3295
# 4       47        F            H                   ALLEY  34.0387 -118.2488
#
# ...

# %%
# Export the processed DataFrame to CSV
merged_data.to_csv("../processed_data/merged_weather_crime_data.csv", index=False)

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2132104 entries, 0 to 2132103
# Data columns (total 16 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   ID               int64
#  1   DATE RPTD        object
#  2   CRIME            object
#  3   VICT AGE         object
#  4   VICT SEX         object
#  5   VICT DESCENT     object
#  6   PLACE            object
#  7   LAT              float64
#  8   LON              float64
#  9   DATETIME OCC     object
#  10  WEAPON CATEGORY  object
#  11  TEMPERATURE      float64
#  12  PERCIPITATION    float64
#  13  WIND SPEED       float64
#  14  RAIN             float64
#  15  SNOWFALL         float64
# dtypes: float64(7), int64(1), object(8)
# memory usage: 260.3+ MB
